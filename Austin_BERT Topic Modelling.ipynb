# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a63a05a-9e6b-4f6d-90a8-2a5230aed728" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a63a05a-9e6b-4f6d-90a8-2a5230aed728">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install bertopic
# !pip install bertopic[visualization]
# !pip install bertopic[spacy]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 72.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 85.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 28.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
# !pip install beautifulsoup4 pandas matplotlib seaborn spacy vaderSentiment scikit-learn
import requests
from bs4 import BeautifulSoup
import pandas as pd
import nltk
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import spacy
import numpy as np
import string
import vaderSentiment
from sklearn.metrics.pairwise import cosine_similarity as cs
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('punkt')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
df = pd.read_csv('Austin_reviews_sentiment.csv')

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stopwords(text):
    words = nltk.word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    filtered_words = ' '.join(filtered_words)
    return filtered_words

# word lemmatization
def lemmatize_words(text):
    words = nltk.word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    filtered_lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    filtered_lemmatized_words = ' '.join(filtered_lemmatized_words)
    return filtered_lemmatized_words

# %%
def remove_punctuation(text):
    # Define a translation table to remove punctuation
    translator = str.maketrans('', '', string.punctuation)

    # Use the translate method to remove punctuation
    text_without_punctuation = text.translate(translator)

    return text_without_punctuation

# %%
def combine_func(text):
    text=remove_stopwords(text)
    text=lemmatize_words(text)
    text=remove_punctuation(text)
    return text

# %%
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
df['cleaned_review'] = df['Comments'].map(combine_func)

# %%
model = BERTopic(verbose=True,n_gram_range=(1,3),nr_topics="auto")
#convert to list
docs = df.cleaned_review.to_list()
topics, probabilities = model.fit_transform(docs)
# Out:
# ...
# Batches:   0%|          | 0/3197 [00:00<?, ?it/s]
# 2023-10-12 13:06:36,297 - BERTopic - Transformed documents to Embeddings
# 2023-10-12 13:09:12,808 - BERTopic - Reduced dimensionality
# 2023-10-12 13:09:25,289 - BERTopic - Clustered reduced embeddings
# 2023-10-12 13:12:35,193 - BERTopic - Reduced number of topics from 329 to 161

# %%
model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
